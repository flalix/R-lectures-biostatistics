# %% [markdown]
# author: Flavio Lichtenstein
# data update:  2019/02/02
# data created: 2016/07/20
# local: Molecular Biology/Inovation & CENTD - Butantan Institute
#
# ### Lecture 07 - regression + ggplot
#
# **mtcars & Fisher Iris**

# %%
head(mtcars)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %%
boxplot(mpg ~ cyl, data=mtcars, col=c("lightblue", "cyan", "tomato"), xlab="cylinder", ylab="mpg")
# Out:
# plot without title

# %%
plot(mtcars$cyl, mtcars$mpg, main="mtcars data", xlab="cylinder", ylab="mpg",  col="navy")
# Out:
# Plot with title “mtcars data”

# %%
fit = lm(mpg ~ cyl, data=mtcars)
fit
# Out:
# Call:
# lm(formula = mpg ~ cyl, data = mtcars)
#
# Coefficients:
# (Intercept)          cyl
#      37,885       -2,876

# %%
plot(mtcars$cyl, mtcars$mpg, main="mtcars data", xlab="cylinder", ylab="mpg",  col="navy")
abline(coefficients(fit), col="red")
# Out:
# Plot with title “mtcars data”

# %%
plot(mtcars$wt, mtcars$mpg, main="mtcars data", xlab="weigth", ylab="mpg",  col="navy")
fit = lm(mpg ~ wt, data=mtcars)
abline(coefficients(fit), col="red")
# Out:
# Plot with title “mtcars data”

# %%
hist(residuals(fit), breaks=8, col="cyan")
# Out:
# Plot with title “Histogram of residuals(fit)”

# %% [markdown]
# ### ggplot
#
# [ggplot gallery](https://www.r-graph-gallery.com/portfolio/ggplot2-package/)
# [graph gallery](https://www.r-graph-gallery.com/all-graphs/)
# [top50](http://r-statistics.co/Top50-Ggplot2-Visualizations-MasterList-R-Code.html)
# [kateto.net](http://kateto.net/network-visualization)

# %%
library(ggplot2)

# %%
ggplot(data=mtcars, aes(wt)) + 
  geom_histogram(binwidth=.7, colour="black", fill="cyan")
# Out:
# plot without title

# %%
ggplot(data=mtcars, aes(wt)) + 
  geom_histogram(binwidth=.7, colour="black", fill="cyan", alpha=.4)
# Out:
# plot without title

# %%
ggplot(data=mtcars, aes(wt)) + 
  geom_density(colour="black", fill="tomato", alpha=.4)
# Out:
# plot without title

# %%
ggplot(data=mtcars, aes(wt)) + 
    geom_histogram(binwidth=.7, colour="black", fill="tomato", alpha=.4) + 
    geom_density(colour="black", fill="tomato", alpha=.4)
# Out:
# plot without title

# %%
ggplot(data=mtcars) + 
    geom_histogram( aes(wt, y=..density..), binwidth=.7, colour="black", fill="cyan", alpha=.4) + 
    geom_density(   aes(wt), colour="black", fill="tomato", alpha=.4)
# Out:
# plot without title

# %%
#-- lets build a 2 columms (value x class) dataframe
df = rbind(
    data.frame(value = mtcars$mpg,  class="mpg"),
    data.frame(value = mtcars$wt,   class="wt"),
    data.frame(value = mtcars$disp, class="disp"),
    data.frame(value = mtcars$hp,   class="hp"),
    data.frame(value = mtcars$cyl,  class="cyl")
) 
table(df$class)
# Out:
#  mpg   wt disp   hp  cyl
#   32   32   32   32   32

# %%
p <- ggplot(mtcars, aes(x=cyl, y=mpg)) + 
      geom_boxplot(aes(group=cyl), colour="navy", fill="cyan", alpha=.2)

p
# Out:
# plot without title

# %%
p <- ggplot(mtcars, aes(x=cyl, y=mpg)) + 
      geom_boxplot(aes(group=cyl), notch=T, colour="navy", fill="cyan", alpha=.2)

p
# Out:
# notch went outside hinges. Try setting notch=FALSE.
# notch went outside hinges. Try setting notch=FALSE.
# plot without title

# %%
p <- ggplot(mtcars, aes(x=cyl, y=mpg)) + 
      geom_boxplot(aes(group=cyl), notch=T, colour="navy", fill="cyan", alpha=.2,
                   outlier.colour="red", outlier.shape=19, outlier.size=6)
p
# Out:
# notch went outside hinges. Try setting notch=FALSE.
# notch went outside hinges. Try setting notch=FALSE.
# plot without title

# %%
p <- ggplot(mtcars, aes(x=cyl, y=mpg)) + 
            geom_boxplot(aes(group=cyl), notch=T, colour="navy", fill="cyan", alpha=.2,
                         outlier.colour="red", outlier.shape=19, outlier.size=6) +
            geom_jitter(shape=16, position=position_jitter(0.2), color="darkgreen")
p
# Out:
# notch went outside hinges. Try setting notch=FALSE.
# notch went outside hinges. Try setting notch=FALSE.
# plot without title

# %%
p <- ggplot(mtcars, aes(x=cyl, y=mpg)) + 
            geom_violin(aes(group=cyl), trim=FALSE, colour="navy", fill="cyan", alpha=.2) +
            geom_jitter(shape=16, position=position_jitter(0.2), color="darkgreen")
p
# Out:
# plot without title

# %%
p <- ggplot(mtcars, aes(x=cyl, y=mpg)) + 
            geom_violin(aes(group=cyl), trim=TRUE, colour="navy", fill="cyan", alpha=.2) +
            geom_jitter(shape=16, position=position_jitter(0.2), color="darkgreen")
p
# Out:
# plot without title

# %%
p <- ggplot(mtcars, aes(x=cyl, y=mpg)) + 
            geom_violin(aes(group=cyl), trim=T, colour="navy", fill="cyan", alpha=.2)  + 
            geom_boxplot(aes(group=cyl), width=0.3, fill="navy", alpha=.3) +
            geom_jitter(shape=16, position=position_jitter(0.2), color="darkgreen")
p
# Out:
# plot without title

# %%
p <- ggplot(mtcars, aes(x = wt, y = mpg)) +
     geom_point()
p
# Out:
# plot without title

# %%
fit <- lm(mpg ~ wt, data=mtcars)
R <- cor(mtcars$mpg, mtcars$wt)

p <- ggplot(mtcars, aes(x = wt, y = mpg)) +
     geom_point() +
     stat_smooth(method = "lm", col = "red") +
     labs(title = paste("Adj R2 = ",signif(summary(fit)$adj.r.squared, 5),
                        "  correlation R = ", signif(R, 5),
                         "\nintercept =",signif(fit$coef[[1]],4 ),
                         " slope =",signif(fit$coef[[2]], 4),
                         "\np-value =",signif(summary(fit)$coef[2,4], 4)),
         x="weigth", y="miles per gallon")

p
# Out:
# plot without title

# %%
summary(fit)
# Out:
# Warning message in printCoefmat(coefs, digits = digits, signif.stars = signif.stars, :
# “NAs introduced by coercion”
# Call:
# lm(formula = mpg ~ wt, data = mtcars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4,5432 -2,3647 -0,1252  1,4096  6,8727
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  37,2851     1,8776  19,858  < 2e-16 ***
# wt           -5,3445     0,5591  -9,559 1,29e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0,001 ‘**’ 0,01 ‘*’ 0,05 ‘.’ 0,1 ‘ ’ 1
#
# Residual standard error: 3,046 on 30 degrees of freedom
# Multiple R-squared:  0,7528,	Adjusted R-squared:  0,7446
# F-statistic: 91,38 on 1 and 30 DF,  p-value: 1,294e-10

# %%
R
# Out:
# [1] -0,8676594
